# %% [markdown]
# ## Numpy = Numerical Python

# %%
import numpy as np

# %% [markdown]
# ### numpy ek library ka actual name h and np ek short alias

# %% [markdown]
# ### Data Structure ndarray means N-Dimensional Array h ,
# ### numpy array banane ke liye hum arr_name = np.array ka use karte hai.

# %%
arr = np.array([ 80, 75, 90, 85 ])
print(arr)
# Out:
# [80 75 90 85]

# %%
### Numpy lka use karte h because list bhot slow hoti h numpy ke comparison me , large amount of data me list minutes, hours tak chali jati h ,
### NumPy ka use indirectly bahut jagah hota hai:

### Data Analysis
### Machine Learning
### Deep Learning
### Artificial Intelligence
### Image Processing
### Scientific Computing

# %% [markdown]
# ## Python List vs Numpy Array

# %%
# python list

numbers = [10,20,30,40]

# %%
# Numpy array
num = np.array([10,20,30,40])

# %% [markdown]
# <!-- Feature  	                Python List	          NumPy Array
# Data types     	              Mixed ho sakte hain	Normally same type
# Numerical calculations	      Comparatively slow	Fast
# Memory usage	              Zyada	                Kam
# Vectorization	              Directly nahi	        Supported
# Mathematical functions	      Limited	            Bahut saare
# Large datasets	              Less efficient       	Efficient  -->

# %%
# list hetrogeneous data store kar sakta h par numpy array hemogenous fata hi store karta hai. sare elements ko same data types me store karta h ,

# %%
# Numpy fats h because C Optimized Backend h , Contiguous Memory use hoti h, Vectorized operations  hote h,
